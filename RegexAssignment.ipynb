# %% [markdown]
# <a href="https://colab.research.google.com/github/Raniel-Ferreira/PY4E-Assignments/blob/main/RegexAssignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To solve this you must remember to upload your .txt file that was given on the assignment.

# %% [markdown]
# ![py assign.png](data:image/png;base64,...)

# %%
import re
fh = open("regex_sum_1154473.txt")
sum = 0
for line in fh:
    num = re.findall('[0-9]+',line)
    length = len(num)
    for i in range(length):
        sum += int(num[i])
print(sum)
# Out:
# 296587
